# %%
import pandas as pd
import numpy as np

# %%
life =pd.read_csv('resources/life expectancy.csv', skiprows=4)
life_df= life[['Country Name','Country Code','Indicator Name','Indicator Code','1990','2019']]
life_df.dropna()
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                               Indicator Name  Indicator Code       1990  \
# 0    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  73.076000
# 1    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  50.607728
# 2    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  45.967000
# 3    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  48.650003
# ...

# %%
life_df['LE_change']=life_df['2019']-life_df['1990']
life_df
# Out:
# c:\Users\Atake\anaconda4\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# ...

# %%
life_expectancy_df= pd.DataFrame(life_df)
life_expectancy_df.to_csv("Resources/Longevity.csv")

# %%
world=pd.read_csv('resources/world_population.csv')

# %%
country_code = world['CCA3']
country_code
# Out:
# 0      AFG
# 1      ALB
# 2      DZA
# 3      ASM
# 4      AND
#       ...
# 229    WLF
# 230    ESH
# 231    YEM
# 232    ZMB
# 233    ZWE
# Name: CCA3, Length: 234, dtype: object

# %%
gdp_df = pd.read_csv("resources/actual GDP.csv", skiprows=4)
select_gdp_df = gdp_df[['Country Name','Country Code','Indicator Name','Indicator Code','1990','2019']]
dropped_gdp_df= select_gdp_df.dropna()

# %%
dropped_gdp_df['GDP_change']=dropped_gdp_df['2019']-dropped_gdp_df['1990']
dropped_gdp_df
# Out:
# c:\Users\Atake\anaconda4\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# 5                        Albania          ALB  GDP (current US$)
# ..                           ...          ...                ...
# 259                        World          WLD  GDP (current US$)
# ...

# %%
actual_gdp_df= pd.DataFrame(dropped_gdp_df)
actual_gdp_df.to_csv("Resources/Actual_Gdp.csv")

# %%
# clean Population data
pop_df = pd.read_csv("resources/pop.csv", skiprows=4)
select_pop_df = pop_df[['Country Name','Country Code','Indicator Name','Indicator Code','1990','2019']]
select_pop_df = select_pop_df.dropna()

# %%
clean_pop_df = select_pop_df.drop(select_pop_df[select_pop_df['2019'] < 500000].index)
clean_pop_df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# 5                        Albania          ALB  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1990         2019
# 1      SP.POP.TOTL  309890664.0  667242712.0
# 2      SP.POP.TOTL   10694796.0   37769499.0
# 3      SP.POP.TOTL  206739024.0  454306063.0
# ...

# %%
clean_pop_df['POP_change']=clean_pop_df['2019']-clean_pop_df['1990']
clean_pop_df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# 5                        Albania          ALB  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1990         2019   POP_change
# 1      SP.POP.TOTL  309890664.0  667242712.0  357352048.0
# 2      SP.POP.TOTL   10694796.0   37769499.0   27074703.0
# ...

# %%
population_df= pd.DataFrame(clean_pop_df)
population_df.to_csv("Resources/population.csv")

# %%
Net_Migration =pd.read_csv("resources/Net Migration.csv", skiprows=4)

# %%
Net_Migration.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', '2021', 'Total Sum'], axis =1, inplace = True)

# %%
country_names_df = Net_Migration[['Country Name','Country Code','Indicator Name','Indicator Code']]
country_names_df
# Out:
#                     Country Name Country Code Indicator Name Indicator Code
# 0                          Aruba          ABW  Net migration    SM.POP.NETM
# 1    Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                    Afghanistan          AFG  Net migration    SM.POP.NETM
# 3     Africa Western and Central          AFW  Net migration    SM.POP.NETM
# 4                         Angola          AGO  Net migration    SM.POP.NETM
# ..                           ...          ...            ...            ...
# 261                       Kosovo          XKX  Net migration    SM.POP.NETM
# 262                  Yemen, Rep.          YEM  Net migration    SM.POP.NETM
# 263                 South Africa          ZAF  Net migration    SM.POP.NETM
# 264                       Zambia          ZMB  Net migration    SM.POP.NETM
# 265                     Zimbabwe          ZWE  Net migration    SM.POP.NETM
#
# [266 rows x 4 columns]

# %%
Net_Migration
# Out:
#                     Country Name Country Code Indicator Name Indicator Code  \
# 0                          Aruba          ABW  Net migration    SM.POP.NETM
# 1    Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                    Afghanistan          AFG  Net migration    SM.POP.NETM
# 3     Africa Western and Central          AFW  Net migration    SM.POP.NETM
# 4                         Angola          AGO  Net migration    SM.POP.NETM
# ..                           ...          ...            ...            ...
# 261                       Kosovo          XKX  Net migration    SM.POP.NETM
# 262                  Yemen, Rep.          YEM  Net migration    SM.POP.NETM
# 263                 South Africa          ZAF  Net migration    SM.POP.NETM
# 264                       Zambia          ZMB  Net migration    SM.POP.NETM
# 265                     Zimbabwe          ZWE  Net migration    SM.POP.NETM
#
# ...

# %%
select_net_migration_df = Net_Migration.sum(axis = 1)
select_net_migration_df
# Out:
# 0         24483.0
# 1     -10700412.0
# 2       3286803.0
# 3      -5711656.0
# 4       1921840.0
#           ...
# 261    -1043320.0
# 262    -1408257.0
# 263      228074.0
# 264       31589.0
# 265    -2651819.0
# Length: 266, dtype: float64

# %%
country_names_df['net_migration'] = select_net_migration_df
country_names_df
# Out:
# c:\Users\Atake\anaconda4\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     Country Name Country Code Indicator Name Indicator Code  \
# 0                          Aruba          ABW  Net migration    SM.POP.NETM
# 1    Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                    Afghanistan          AFG  Net migration    SM.POP.NETM
# 3     Africa Western and Central          AFW  Net migration    SM.POP.NETM
# 4                         Angola          AGO  Net migration    SM.POP.NETM
# ..                           ...          ...            ...            ...
# ...

# %%
Migration_df= pd.DataFrame(country_names_df)
Migration_df.to_csv("Resources/Net_mig_nat_bir.csv")

# %%
nat_birth_rate =pd.read_csv("resources/Birth rate.csv", skiprows=4)
nat_birth_rate.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', 'Average'], axis =1, inplace = True)
mean_nat_birth_rate = nat_birth_rate.mean(axis = 1)
mean_nat_birth_rate
# Out:
# 0      13.693533
# 1      39.323510
# 2      45.320767
# 3      41.793715
# 4      46.196700
#          ...
# 261    18.351367
# 262    39.365900
# 263    23.216900
# 264    43.152567
# 265    34.660400
# Length: 266, dtype: float64

# %%
country_names_df['mean_nat_birth_rate'] = mean_nat_birth_rate
country_names_df
# Out:
# c:\Users\Atake\anaconda4\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     Country Name Country Code Indicator Name Indicator Code  \
# 0                          Aruba          ABW  Net migration    SM.POP.NETM
# 1    Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                    Afghanistan          AFG  Net migration    SM.POP.NETM
# 3     Africa Western and Central          AFW  Net migration    SM.POP.NETM
# 4                         Angola          AGO  Net migration    SM.POP.NETM
# ..                           ...          ...            ...            ...
# ...

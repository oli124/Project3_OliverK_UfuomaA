# %%
import pandas as pd
import numpy as np

# %%
world=pd.read_csv('resources/world_population.csv')

# %%
world.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
world.drop(['Rank', 'CCA3', '2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population'], axis= 1, inplace= True)

# %%
world.rename(columns={'Country/Territory': 'Country Name'}, inplace=True)

# %%
world

# %%
pop_df = pd.read_csv("resources/pop.csv", skiprows=3)

# %%
pop_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
gdp_df = pd.read_csv("resources/gdp.csv", skiprows=3)
gdp_df.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', '2021'], axis =1, inplace = True)
gdp_df
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code      1990      1991      1992       1993      1994  \
# ...

# %%
# clean Population data
clean_pop = pop_df.drop(['Country Code', 'Indicator Name', 'Indicator Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1991', '1992','1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '1993','1994','2020', '2021',
       'Unnamed: 66'], axis=1, inplace=True)

# %%
population_df= pd.DataFrame(pop_df)
population_df.to_csv("Resources/population.csv")

# %%
Net_Migration =pd.read_csv("resources/Net Migration.csv", skiprows=4)

# %%
Net_Migration.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', '2021'], axis =1, inplace = True)

# %%
Net_Migration

# %%
Migration_df= pd.DataFrame(Net_Migration)
Migration_df.to_csv("Resources/Migration.csv")

# %%
nat_birth_rate =pd.read_csv("resources/Birth rate.csv", skiprows=4)
nat_birth_rate.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', ], axis =1, inplace = True)
nat_birth_rate
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                            Indicator Name  Indicator Code       1990  \
# 0    Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  18.662000
# 1    Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  44.230719
# 2    Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  51.423000
# 3    Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  44.676194
# ...

# %%
Natural_birth_rate_df= pd.DataFrame(nat_birth_rate)
Natural_birth_rate_df.to_csv("Resources/Natural_birth_rate.csv")

# %%
population = pop_df
GDP = gdp_df
World = world

# %%
# merge dataset
country = pd.merge(world, population, on='Country Name', how='left')
country = pd.merge(country, GDP, on='Country Name', how='left')

# %%
country

# %%
country_df = country.dropna()
country_df

# %%
country_df.info()

# %% [markdown]
# top 50 countries based on individual year

# %%
pd.concat([country_df, s.rename('index')], axis=1)

# %%
country_df['new_col'] = range(1, len(country_df) + 1)

# %%
country_df

# %%
sort_country_df = country_df.sort_values(by= '1990',ascending= True)  
sort_country_df.head(10)

# %% [markdown]
# how to set index in ascending order

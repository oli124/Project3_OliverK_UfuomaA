# %%
import pandas as pd

# %%
world=pd.read_csv('resources/world_population.csv')

# %%
world.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
world.drop(['Rank', 'CCA3', '2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population'], axis= 1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21284\994751667.py in <module>
#       1 world.drop(['Rank', 'CCA3', '2022 Population', '2020 Population', '2015 Population',
#       2        '2010 Population', '2000 Population', '1990 Population',
# ----> 3        '1980 Population', '1970 Population'], axis= 1, inplace= True)
#       4 world.rename(columns={'Country/Territory': 'Country', 'Density (per km²)':'Density',
#       5                       'Area (km²)':'Area'}, inplace=True)
#
# c:\Users\Atake\anaconda4\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ...

# %%
world.rename(columns={'Country': 'Country Name'}, inplace=True)

# %%
world
# Out:
#                Country           Capital Continent     Area   Density  \
# 0          Afghanistan             Kabul      Asia   652230   63.0587
# 1              Albania            Tirana    Europe    28748   98.8702
# 2              Algeria           Algiers    Africa  2381741   18.8531
# 3       American Samoa         Pago Pago   Oceania      199  222.4774
# 4              Andorra  Andorra la Vella    Europe      468  170.5641
# ..                 ...               ...       ...      ...       ...
# 229  Wallis and Futuna          Mata-Utu   Oceania      142   81.4930
# 230     Western Sahara          El Aaiún    Africa   266000    2.1654
# 231              Yemen             Sanaa      Asia   527968   63.8232
# 232             Zambia            Lusaka    Africa   752612   26.5976
# 233           Zimbabwe            Harare    Africa   390757   41.7665
#
#      Growth Rate  World Population Percentage
# 0         1.0257                         0.52
# ...

# %%
pop_df = pd.read_csv("resources/pop.csv", skiprows=3)
pop_df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
gdp_df = pd.read_csv("resources/gdp.csv", skiprows=3)
gdp_df
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code  1960      1961      1962      1963       1964  \
# ...

# %%
# clean Population data
clean_pop = pop_df.drop(['2020', '2021',
       'Unnamed: 66'], axis=1, inplace=True)

# %%
gdp_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
# Clean Gdp Data
clean_gdp = gdp_df.drop(['Indicator Name', 'Indicator Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', '2021', 'Unnamed: 66'], axis =1, inplace = True)

# %%
pop_df.columns
# Out:
# Index(['Country Name', 'Country Code', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
gdp_df.columns
# Out:
# Index(['Country Name', 'Country Code', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
pop_df.describe()
# Out:
#                1990          1991          1992          1993          1994  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   2.098278e+08  2.135356e+08  2.171880e+08  2.208192e+08  2.244211e+08
# std    6.674312e+08  6.792168e+08  6.906788e+08  7.019841e+08  7.132145e+08
# min    9.182000e+03  9.354000e+03  9.466000e+03  9.517000e+03  9.559000e+03
# 25%    1.040616e+06  1.070266e+06  1.084441e+06  1.097374e+06  1.112846e+06
# 50%    7.096194e+06  7.244891e+06  7.382050e+06  7.494800e+06  7.486091e+06
# 75%    4.787807e+07  4.993743e+07  5.201155e+07  5.217920e+07  5.192140e+07
# max    5.293517e+09  5.382656e+09  5.470277e+09  5.556723e+09  5.642129e+09
#
#                1995          1996          1997          1998          1999  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   2.279961e+08  2.315714e+08  2.351344e+08  2.386732e+08  2.421788e+08
# ...

# %%
gdp_df.describe()
# Out:
#              1990        1991        1992        1993        1994        1995  \
# count  207.000000  217.000000  218.000000  221.000000  222.000000  224.000000
# mean     3.425752    1.442649    1.627153    1.970313    2.231494    3.903634
# std      6.718609    7.730023    8.181973    6.816768    7.307229    4.946079
# min    -14.788226  -64.047107  -44.899999  -29.300002  -50.248067  -12.416322
# 25%      0.009606   -0.189281   -0.116799   -0.573681    1.024319    2.327407
# 50%      3.328818    1.801170    2.081645    2.181890    3.295334    3.914503
# 75%      5.395860    4.599987    5.472468    4.924690    5.367588    6.009119
# max     57.817828   49.447379   34.745320   33.990468   21.221411   35.224078
#
#              1996        1997        1998        1999  ...        2010  \
# count  234.000000  234.000000  237.000000  238.000000  ...  254.000000
# mean     4.829968    5.016156    3.499402    3.299939  ...    4.543144
# ...

# %%
population = pop_df
GDP = gdp_df
World = world

# %%
# merge dataset
country = pd.merge(world, population, on='Country Name', how='left')
country = pd.merge(country, GDP, on='Country Name', how='left')

# %% [markdown]
# problem here, don't know why it merged and created the years in 2

# %%
country
# Out:
#           Country Name           Capital Continent     Area   Density  \
# 0          Afghanistan             Kabul      Asia   652230   63.0587
# 1              Albania            Tirana    Europe    28748   98.8702
# 2              Algeria           Algiers    Africa  2381741   18.8531
# 3       American Samoa         Pago Pago   Oceania      199  222.4774
# 4              Andorra  Andorra la Vella    Europe      468  170.5641
# ..                 ...               ...       ...      ...       ...
# 229  Wallis and Futuna          Mata-Utu   Oceania      142   81.4930
# 230     Western Sahara          El Aaiún    Africa   266000    2.1654
# 231              Yemen             Sanaa      Asia   527968   63.8232
# 232             Zambia            Lusaka    Africa   752612   26.5976
# 233           Zimbabwe            Harare    Africa   390757   41.7665
#
#      Growth Rate  World Population Percentage Country Code_x      1990_x  \
# ...

# %%
country_df = country.dropna()
country_df
# Out:
#             Country Name           Capital      Continent     Area   Density  \
# 1                Albania            Tirana         Europe    28748   98.8702
# 2                Algeria           Algiers         Africa  2381741   18.8531
# 4                Andorra  Andorra la Vella         Europe      468  170.5641
# 5                 Angola            Luanda         Africa  1246700   28.5466
# 7    Antigua and Barbuda      Saint John’s  North America      442  212.1335
# ..                   ...               ...            ...      ...       ...
# 224           Uzbekistan          Tashkent           Asia   447400   77.3975
# 225              Vanuatu         Port-Vila        Oceania    12189   26.8061
# 228              Vietnam             Hanoi           Asia   331212  296.4472
# 232               Zambia            Lusaka         Africa   752612   26.5976
# 233             Zimbabwe            Harare         Africa   390757   41.7665
#
# ...

# %%
clean_country = country_df.drop(['Country Code_y', '1990_y', '1991_y', '1992_y',
       '1993_y', '1994_y', '1995_y', '1996_y', '1997_y', '1998_y', '1999_y',
       '2000_y', '2001_y', '2002_y', '2003_y', '2004_y', '2005_y', '2006_y',
       '2007_y', '2008_y', '2009_y', '2010_y', '2011_y', '2012_y', '2013_y',
       '2014_y', '2015_y', '2016_y', '2017_y', '2018_y', '2019_y'], axis=1, inplace=True)
# Out:
# c:\Users\Atake\anaconda4\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# Need to filter based on population but i have two sets of population data
